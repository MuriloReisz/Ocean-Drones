# %% [markdown]
# # **Procedimentos Roboflow**

# %%
# !pip install roboflow

# %%
from IPython.display import Image, display
from roboflow import Roboflow
rf = Roboflow(api_key="fcZVopVBbrYeR1RKyzZ0")
project = rf.workspace("fiap-ufhuo").project("ocean-detection-mq96u")
version = project.version(1)
dataset = version.download("ultralytics")
model = project.version(1).model
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# # **INVASORES**

# %% [markdown]
# ## **Alga Assassina**

# %%
# Imagem para teste do modelo:
print(model.predict("/content/alga11.jpg", confidence=40, overlap=30).json())
# Out:
# {'predictions': [{'x': 126.0, 'y': 156.5, 'width': 74.0, 'height': 235.0, 'confidence': 0.9734740257263184, 'class': 'invasores-alga-assassina', 'class_id': 0, 'detection_id': '5fd86fc6-b9b0-4906-bae8-5f5744ed9070', 'image_path': '/content/alga11.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 67.0, 'y': 197.0, 'width': 78.0, 'height': 158.0, 'confidence': 0.9658690690994263, 'class': 'invasores-alga-assassina', 'class_id': 0, 'detection_id': 'f6de5bd0-bbba-488c-a172-5da72170f326', 'image_path': '/content/alga11.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '183', 'height': '276'}}

# %%
# Imagem para teste do modelo:
model.predict("/content/alga11.jpg", confidence=40, overlap=30).save("/content/alga11-processed.jpg")

# %%
display(Image(filename="/content/alga11-processed.jpg"))

# %% [markdown]
# ##**Caramujo**

# %%
# Imagem para teste do modelo:
print(model.predict("/content/caramujo10.jpg", confidence=40, overlap=30).json())
# Out:
# {'predictions': [{'x': 378.5, 'y': 161.0, 'width': 193.0, 'height': 322.0, 'confidence': 0.988294243812561, 'class': 'invasores-caramujo', 'class_id': 1, 'detection_id': '50e12656-beef-4d8c-a793-a8c7a3884fe9', 'image_path': '/content/caramujo10.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 131.5, 'y': 168.0, 'width': 175.0, 'height': 286.0, 'confidence': 0.9800364971160889, 'class': 'invasores-caramujo', 'class_id': 1, 'detection_id': '39a6789f-12c3-4231-883a-2892c5dd6f85', 'image_path': '/content/caramujo10.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '512', 'height': '351'}}

# %%
# Imagem para teste do modelo:
model.predict("/content/caramujo10.jpg", confidence=40, overlap=30).save("/content/caramujo10-processed.jpg")

# %%
display(Image(filename="/content/caramujo10-processed.jpg"))

# %% [markdown]
# ## **Carangueijo Verde**

# %%
# Imagem para teste do modelo:
print(model.predict("/content/caramgueijo-verde2.jpg", confidence=40, overlap=30).json())
# Out:
# {'predictions': [{'x': 255.5, 'y': 258.5, 'width': 479.0, 'height': 389.0, 'confidence': 0.953567624092102, 'class': 'invasores-carangueijo-verde', 'class_id': 2, 'detection_id': '14539f77-711c-45ff-a5da-16cebbf50d81', 'image_path': '/content/caramgueijo-verde2.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '500', 'height': '500'}}

# %%
# Imagem para teste do modelo:
model.predict("/content/caramgueijo-verde2.jpg", confidence=40, overlap=30).save("caramgueijo-verde2-processed.jpg")

# %%
display(Image(filename="caramgueijo-verde2-processed.jpg"))

# %% [markdown]
# ##**Peixe Leão**

# %%
# Imagem para teste do modelo:
print(model.predict("/content/peixe-leao6.jpg", confidence=40, overlap=30).json())
# Out:
# {'predictions': [{'x': 145.5, 'y': 98.0, 'width': 201.0, 'height': 192.0, 'confidence': 0.4367019534111023, 'class': 'invasores-peixe-leao', 'class_id': 3, 'detection_id': '291e801f-18c0-40ce-93b8-c091c03f95eb', 'image_path': '/content/peixe-leao6.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '259', 'height': '194'}}

# %%
# Imagem para teste do modelo:
model.predict("/content/peixe-leao6.jpg", confidence=40, overlap=30).save("/content/peixe-leao6-processed.jpg")

# %%
display(Image(filename="/content/peixe-leao6-processed.jpg"))

# %% [markdown]
# ##**Tilápia**

# %%
# Imagem para teste do modelo:
print(model.predict("/content/tilapia4.jpg", confidence=40, overlap=30).json())
# Out:
# {'predictions': [{'x': 562, 'y': 519, 'width': 671, 'height': 228, 'confidence': 0.9788107872009277, 'class': 'invasores-tilapia', 'class_id': 4, 'detection_id': '8edc9a58-8015-45a1-8eaf-44d1f394e20e', 'image_path': '/content/tilapia4.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 780, 'y': 114, 'width': 239, 'height': 177, 'confidence': 0.9624198079109192, 'class': 'invasores-tilapia', 'class_id': 4, 'detection_id': '270ec382-fc9b-41d4-ba4c-0102ef963d47', 'image_path': '/content/tilapia4.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 387, 'y': 127, 'width': 528, 'height': 168, 'confidence': 0.9620127081871033, 'class': 'invasores-tilapia', 'class_id': 4, 'detection_id': '28389a0f-7cdc-47cb-95a1-ebcdd3239530', 'image_path': '/content/tilapia4.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 428, 'y': 310, 'width': 659, 'height': 206, 'confidence': 0.940035343170166, 'class': 'invasores-tilapia', 'class_id': 4, 'detection_id': 'df7a4bd4-0f92-406d-92f2-38d4d3a6
# ...

# %%
# Imagem para teste do modelo:
model.predict("/content/tilapia4.jpg", confidence=40, overlap=30).save("/content/tilapia4-processed.jpg")

# %%
display(Image(filename="/content/tilapia4-processed.jpg"))

# %% [markdown]
# # **NATIVOS**

# %% [markdown]
# ##**Carangueijo Azul**

# %%
# Imagem para teste do modelo:
print(model.predict("/content/carangueijo-azul1.jpg", confidence=40, overlap=30).json())
# Out:
# {'predictions': [{'x': 305.5, 'y': 218.5, 'width': 567.0, 'height': 311.0, 'confidence': 0.4791887700557709, 'class': 'nativos-carangueijo-azul', 'class_id': 13, 'detection_id': 'da9aecb9-2415-4929-8bc4-05182e5f19d1', 'image_path': '/content/carangueijo-azul1.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '614', 'height': '416'}}

# %%
# Imagem para teste do modelo:
model.predict("/content/carangueijo-azul1.jpg", confidence=40, overlap=30).save("/content/carangueijo-azul1-processed.jpg")

# %%
display(Image(filename="/content/carangueijo-azul1-processed.jpg"))

# %% [markdown]
# ## **Carangueijo Uca**

# %%
# Imagem para teste do modelo:
print(model.predict("/content/carangueijo-uca5.jpg", confidence=40, overlap=30).json())
# Out:
# {'predictions': [{'x': 421, 'y': 341, 'width': 661, 'height': 465, 'confidence': 0.9823817014694214, 'class': 'nativo-carangueijo-uca', 'class_id': 9, 'detection_id': 'ecea5377-2e1c-4de7-a34e-452fabe7a217', 'image_path': '/content/carangueijo-uca5.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '833', 'height': '640'}}

# %%
# Imagem para teste do modelo:
model.predict("/content/carangueijo-uca5.jpg", confidence=40, overlap=30).save("/content/carangueijo-uca5-processed.jpg")

# %%
display(Image(filename="/content/carangueijo-uca5-processed.jpg"))

# %% [markdown]
# ## **Camarão**

# %%
# Imagem para teste do modelo:
print(model.predict("/content/camarao4.jpg", confidence=40, overlap=30).json())
# Out:
# {'predictions': [{'x': 161.0, 'y': 89.5, 'width': 172.0, 'height': 117.0, 'confidence': 0.9761789441108704, 'class': 'nativos-camarao', 'class_id': 12, 'detection_id': '5d61b513-809e-4f5b-b3ee-be5ef02a89fb', 'image_path': '/content/camarao4.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 34.0, 'y': 88.0, 'width': 68.0, 'height': 112.0, 'confidence': 0.9722094535827637, 'class': 'nativos-camarao', 'class_id': 12, 'detection_id': 'cd9c85d0-ad04-44ef-a7ac-4c5bcdef3df5', 'image_path': '/content/camarao4.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '300', 'height': '171'}}

# %%
# Imagem para teste do modelo:
model.predict("/content/camarao4.jpg", confidence=40, overlap=30).save("/content/camarao4-processed.jpg")

# %%
display(Image(filename="/content/camarao4-processed.jpg"))

# %% [markdown]
# ##**Garça Branca**

# %%
# Imagem para teste do modelo:
print(model.predict("/content/garca6.jpg", confidence=40, overlap=30).json())
# Out:
# {'predictions': [{'x': 200, 'y': 290, 'width': 313, 'height': 369, 'confidence': 0.9831083416938782, 'class': 'nativo-garca-branca', 'class_id': 10, 'detection_id': 'fd7ddcb4-2d78-4118-91d7-fe736608bfd5', 'image_path': '/content/garca6.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 433, 'y': 336, 'width': 382, 'height': 627, 'confidence': 0.9649611711502075, 'class': 'nativo-garca-branca', 'class_id': 10, 'detection_id': 'e1df71d0-64ec-4d0e-b88a-e9586749d3d7', 'image_path': '/content/garca6.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '780', 'height': '653'}}

# %%
# Imagem para teste do modelo:
model.predict("/content/garca6.jpg", confidence=40, overlap=30).save("/content/garca6-processed.jpg")

# %%
display(Image(filename="/content/garca6-processed.jpg"))

# %% [markdown]
# ##**Killi Mangue**

# %%
# Imagem para teste do modelo:
print(model.predict("/content/killi-mangue9.jpg", confidence=40, overlap=30).json())
# Out:
# {'predictions': [{'x': 229, 'y': 294, 'width': 450, 'height': 163, 'confidence': 0.9727368354797363, 'class': 'nativo-killi-mangue', 'class_id': 11, 'detection_id': 'bbb5c7e4-c62e-4763-801e-74f6fafbaf89', 'image_path': '/content/killi-mangue9.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 382, 'y': 222, 'width': 462, 'height': 433, 'confidence': 0.8672351837158203, 'class': 'nativo-killi-mangue', 'class_id': 11, 'detection_id': '5968ad80-331f-4809-a751-0c391aeb61c4', 'image_path': '/content/killi-mangue9.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '643', 'height': '477'}}

# %%
# Imagem para teste do modelo:
model.predict("/content/killi-mangue9.jpg", confidence=40, overlap=30).save("/content/killi-mangue9-processed.jpg")

# %%
display(Image(filename="/content/killi-mangue9-processed.jpg"))

# %% [markdown]
# # **LIXOS**

# %% [markdown]
# ##**Cigarro**

# %%
# Imagem para teste do modelo:
print(model.predict("/content/cigarro5.jpg", confidence=40, overlap=30).json())
# Out:
# {'predictions': [{'x': 607, 'y': 358, 'width': 184, 'height': 76, 'confidence': 0.9857914447784424, 'class': 'lixos', 'class_id': 8, 'detection_id': 'e7abbf11-b923-475f-baef-3d706f1badcb', 'image_path': '/content/cigarro5.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 88, 'y': 339, 'width': 138, 'height': 92, 'confidence': 0.9835323095321655, 'class': 'lixos', 'class_id': 8, 'detection_id': '7c72791e-0d7e-4472-952a-32f8fd923fe0', 'image_path': '/content/cigarro5.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 429, 'y': 89, 'width': 218, 'height': 88, 'confidence': 0.9792531132698059, 'class': 'lixos', 'class_id': 8, 'detection_id': '9c276d1a-2160-428c-9105-25eb027583b2', 'image_path': '/content/cigarro5.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 518, 'y': 282, 'width': 103, 'height': 88, 'confidence': 0.9782066941261292, 'class': 'lixos', 'class_id': 8, 'detection_id': '2ec67162-5a34-48c5-be5d-a8422013aa49', 'image_path': '/content/cigarro5.jpg', 'predic
# ...

# %%
# Imagem para teste do modelo:
model.predict("/content/cigarro5.jpg", confidence=40, overlap=30).save("/content/cigarro5-processed.jpg")

# %%
display(Image(filename="/content/cigarro5-processed.jpg"))

# %% [markdown]
# ##**Garrafas**

# %%
# Imagem para teste do modelo:
print(model.predict("/content/garrafa10.jpg", confidence=40, overlap=30).json())
# Out:
# {'predictions': [{'x': 384, 'y': 192, 'width': 591, 'height': 122, 'confidence': 0.9875752329826355, 'class': 'lixo-garrafa', 'class_id': 6, 'detection_id': 'b28177fb-7dbd-4ae5-9b07-d56a4bf802a0', 'image_path': '/content/garrafa10.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '750', 'height': '460'}}

# %%
# Imagem para teste do modelo:
model.predict("/content/garrafa10.jpg", confidence=40, overlap=30).save("/content/garrafa10-processed.jpg")

# %%
display(Image(filename="/content/garrafa10-processed.jpg"))

# %% [markdown]
# ##**Sacolas**

# %%
# Imagem para teste do modelo:
print(model.predict("/content/sacola11.jpg", confidence=40, overlap=30).json())
# Out:
# {'predictions': [{'x': 186.5, 'y': 97.0, 'width': 101.0, 'height': 102.0, 'confidence': 0.8421787023544312, 'class': 'lixo-sacola', 'class_id': 7, 'detection_id': '9fa17bd7-0ff2-4338-a845-2735b460c189', 'image_path': '/content/sacola11.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 114.0, 'y': 77.5, 'width': 218.0, 'height': 135.0, 'confidence': 0.5061366558074951, 'class': 'lixo-sacola', 'class_id': 7, 'detection_id': '8140c1ff-ee7d-4e6d-a221-2db097d78c73', 'image_path': '/content/sacola11.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '275', 'height': '183'}}

# %%
# Imagem para teste do modelo:
model.predict("/content/sacola11.jpg", confidence=40, overlap=30).save("/content/sacola11-processed.jpg")

# %%
display(Image(filename="/content/sacola11-processed.jpg"))
